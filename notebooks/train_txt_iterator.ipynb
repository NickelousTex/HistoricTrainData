# %% [markdown]
# # Notes

# %% [markdown]
#  - Do we know what timezone the files are for? For example if we have a westcoast train line, are the times within it in PDT? Or is it standardized UTC?
#  - Are we happy with the structure of the dictionaries?
#     ```
#      date: timestamp
#      train: {
#        <name>: str,
#        <number>: {
#            <schedule_array> <-- Do we want to find a better structure
#     ```
#  - Given there are 'schedule' days that seem to add +1 or more days to the date - do we just want to include that in the timestamps vs having an entirely seperate column/element for them? If something departed actual time, can we assume that the scedule day applies to the actual time as well?
#  - Do we want to take the train header line info (if present) and add that to our comments? If so - where?
#  - Why are there so many missing 'arrival' times? What happens during those? Do we want to infer arrival to the next station based on departure or estimate time for travel?

# %% [markdown]
# # Setup functions

# %%
from datetime import datetime, timedelta

# %%
def read_file(file_path):
    '''
    Extracts and returns the train name, table index, and relevant schedule lines from the provided list of file lines, based on the known file structure
    '''
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            return lines
    except FileNotFoundError:
        return f"Error: File not found: {file_path}"

# %%
def process_lines(lines):
    '''
    Takes in file lines and returns the train name, the table index and the relevant schedule lines
    '''
    for idx, line in enumerate(lines):
        if line.startswith("* THIS TRAIN"):
            # Skip annoying header lines if present and only get the train line info
            next
        else:
            train_name_line = line.replace("* ", "").strip()
            table_index_line = lines[idx+9] # based on the structure it should always be this line - but if not we can serach for the VVV line
            # Skip the next lines after the train name to ignore the glossary which is not needed as we know the structure
            schedule_lines = lines[idx+10:]
            return train_name_line, table_index_line, schedule_lines
            break # we don't need to continue given we have all the info we actually want

# %%
def determin_table_indexing(table_index_line):
    '''
    assumes we have the right index line that looks similar to:
           "* V    V  V     V  V     V     V     V"
    '''
    return [i for i, char in enumerate(table_index_line) if char == 'V']

# %%
def timestamp_conversion(time_str, date_time, add_day = None):
    '''
    Converts a time string (e.g., '915A') to an epoch timestamp using the provided date, adjusting for AM/PM and optionally adding days if specified. 
    Returns None if the input time string is empty.
    '''
    if time_str:
        hour = int(time_str[:-3]) 
        minute = int(time_str[-3:-1])
        ampm = time_str[-1]
    
        if ampm == 'P' and hour != 12:
            hour += 12
        elif ampm == 'A' and hour == 12:
            hour = 0
        
        now = datetime.now()
        dt_new = date_time.replace(hour=hour, minute=minute, second=0, microsecond=0)
        # Account for the 
        if add_day:
            dt_new += timedelta(days=int(add_day))
        return(dt_new.timestamp())
    else:
        None

# %%
def parse_schedule_info(schedule_line, indices, train_date_time):
    '''
    Parses a single schedule line using the provided field indices and train date,
    extracting relevant information into a dictionary with station codes,
    arrival/departure times (converted to epoch), and any additional comments.
    '''
    slice_points = [0] + indices + [len(schedule_line)]

    elements = []
    for i in range(len(slice_points) - 1):
        field = schedule_line[slice_points[i]:slice_points[i+1]].strip()
        if not field or field == '*':
            elements.append(None)
        else:
            elements.append(field)

    # Extract fields based on positions
    # print(elements) # debug
    result = {
        "station_code": elements[1],
        "scheduled_arrival_day": elements[2],
        "schedule_arrival_time": timestamp_conversion(elements[3], train_date_time, elements[2]), # TODO - we can add the extra day to the schedule if possible?
        "schedule_departure_day": elements[4],
        "schedule_departure_time": timestamp_conversion(elements[5], train_date_time),
        "actual_arrival_time": timestamp_conversion(elements[6], train_date_time), # TODO - can we add schedule arrival day as well? How do we know it's true?
        "actual_departure_time": timestamp_conversion(elements[7], train_date_time), # TODO - can we add schedule departure day as well? How do we know it's true?
        "comments": ' '.join(elements[8:])  # Join the rest as comments
    }
    return result

# %% [markdown]
# --------

# %% [markdown]
# # Run example files

# %%
file_path = "20_20230129.txt"
# file_path = "28_20240119.txt"

file_lines = read_file(file_path)
metadata = file_path.split("_")
train_num = metadata[0] # TODO - we could just do all of this in our read file function and return to make this more concise
train_date = metadata[1].strip(".txt") # TODO - what are the timezones for these files? Can we account for that somehow?
train_date_time = datetime.strptime(train_date, "%Y%m%d")
train_dict = {
    "date": train_date_time.timestamp(), 
    "train": {train_name: 
              {train_num:[]}
             }
}

# %%
train_name, table_index_line, schedule = process_lines(file_lines)
table_index = determin_table_indexing(table_index_line)
if isinstance(schedule, list):
    for line in schedule:
        train_dict["train"][train_name][train_num].append(parse_schedule_info(line, table_index, train_date_time))
else:
    print('here')
    print(schedule) # Print obj to debug #TODO have error message and handle gracefully

# %%
train_dict
# Out:
# {'date': 1674968400.0,
#  'train': {'Crescent': {'20': [{'station_code': 'NOL',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675001700.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675001700.0,
#      'comments': 'Departed:  On time.'},
#     {'station_code': 'SDL',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675005120.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675006380.0,
#      'comments': 'Departed:  21 minutes late.'},
#     {'station_code': 'PIC',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675006620.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675008300.0,
#      'comments': 'Departed:  28 minutes late.'},
#     {'station_code': 'HBG',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675010700.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675012560.0,
#      'comments': 'Departed:  31 minutes late.'},
#     {'station_code': 'LAU',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675012800.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675014540.0,
#      'comments': 'Departed:  29 minutes late.'},
#     {'station_code': 'MEI',
#      'scheduled_arrival_day': '1',
#      'schedule_arrival_time': 1675103520.0,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675017420.0,
#      'actual_arrival_time': 1675019700.0,
#      'actual_departure_time': 1675020960.0,
#      'comments': 'Arrived:  43 minutes late.          | Departed:  59 minutes late.'},
#     {'station_code': 'TCL',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675023240.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675028460.0,
#      'comments': 'Departed:  1 hour, 27 minutes late.'},
#     {'station_code': 'BHM',
#      'scheduled_arrival_day': '1',
#      'schedule_arrival_time': 1675116900.0,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675031040.0,
#      'actual_arrival_time': 1675033200.0,
#      'actual_departure_time': 1675034040.0,
#      'comments': 'Arrived:  45 minutes late.          | Departed:  50 minutes late.'},
#     {'station_code': 'ATN',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675036740.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675040940.0,
#      'comments': 'Departed:  1 hour, 10 minutes late.'},
#     {'station_code': 'ATL',
#      'scheduled_arrival_day': '1',
#      'schedule_arrival_time': 1675137600.0,
#      'schedule_departure_day': '1',
#      'schedule_departure_time': 1675052940.0,
#      'actual_arrival_time': 1675053240.0,
#      'actual_departure_time': 1674969600.0,
#      'comments': 'Arrived:  34 minutes late.          | Departed:  51 minutes late.'},
#     {'station_code': 'GNS',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674969840.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674972780.0,
#      'comments': 'Departed:  49 minutes late.'},
#     {'station_code': 'TCA',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674972300.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674975300.0,
#      'comments': 'Departed:  50 minutes late.'},
#     {'station_code': 'CSN',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674974460.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674977520.0,
#      'comments': 'Departed:  51 minutes late.'},
#     {'station_code': 'GRV',
#      'scheduled_arrival_day': '2',
#      'schedule_arrival_time': 1675149480.0,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674976980.0,
#      'actual_arrival_time': 1674979680.0,
#      'actual_departure_time': 1674979920.0,
#      'comments': 'Arrived:  50 minutes late.          | Departed:  49 minutes late.'},
#     {'station_code': 'SPB',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674979440.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674982380.0,
#      'comments': 'Departed:  49 minutes late.'},
#     {'station_code': 'GAS',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674983040.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674986640.0,
#      'comments': 'Departed:  1 hour, late.'},
#     {'station_code': 'CLT',
#      'scheduled_arrival_day': '2',
#      'schedule_arrival_time': 1675159560.0,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674988260.0,
#      'actual_arrival_time': 1674988200.0,
#      'actual_departure_time': 1674989220.0,
#      'comments': 'Arrived:  24 minutes late.          | Departed:  16 minutes late.'},
#     {'station_code': 'SAL',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674991020.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674991440.0,
#      'comments': 'Departed:  7 minutes late.'},
#     {'station_code': 'HPT',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674993660.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674993660.0,
#      'comments': 'Departed:  On time.'},
#     {'station_code': 'GRO',
#      'scheduled_arrival_day': '2',
#      'schedule_arrival_time': 1675167720.0,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674995340.0,
#      'actual_arrival_time': 1674994620.0,
#      'actual_departure_time': 1674995340.0,
#      'comments': 'Arrived:  5 minutes early.          | Departed:  On time.'},
#     {'station_code': 'DAN',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1674998880.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1674998880.0,
#      'comments': 'Departed:  On time.'},
#     {'station_code': 'LYH',
#      'scheduled_arrival_day': '2',
#      'schedule_arrival_time': 1675175820.0,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675003260.0,
#      'actual_arrival_time': 1675002840.0,
#      'actual_departure_time': 1675003260.0,
#      'comments': 'Arrived:  3 minutes early.          | Departed:  On time.'},
#     {'station_code': 'CVS',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675007640.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675007700.0,
#      'comments': 'Departed:  1 minute late.'},
#     {'station_code': 'CLP',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675010760.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675010820.0,
#      'comments': 'Departed:  1 minute late.'},
#     {'station_code': 'MSS',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675012800.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675012860.0,
#      'comments': 'Departed:  1 minute late.'},
#     {'station_code': 'ALX',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675016520.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675016040.0,
#      'comments': 'Departed:  8 minutes early.'},
#     {'station_code': 'WAS',
#      'scheduled_arrival_day': '2',
#      'schedule_arrival_time': 1675190700.0,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675019700.0,
#      'actual_arrival_time': 1675017120.0,
#      'actual_departure_time': 1675019760.0,
#      'comments': 'Arrived:  13 minutes early.         | Departed:  1 minute late.'},
#     {'station_code': 'BWI',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675021260.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675022820.0,
#      'comments': 'Departed:  26 minutes late.'},
#     {'station_code': 'BAL',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675022280.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675024860.0,
#      'comments': 'Departed:  43 minutes late.'},
#     {'station_code': 'WIL',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675025400.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675027800.0,
#      'comments': 'Departed:  40 minutes late.'},
#     {'station_code': 'PHL',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675027260.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675029240.0,
#      'comments': 'Departed:  33 minutes late.'},
#     {'station_code': 'TRE',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675029060.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675030980.0,
#      'comments': 'Departed:  32 minutes late.'},
#     {'station_code': 'PJC',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675029840.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675031640.0,
#      'comments': 'Departed:  30 minutes late.'},
#     {'station_code': 'NBK',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675030920.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675032420.0,
#      'comments': 'Departed:  25 minutes late.'},
#     {'station_code': 'MET',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675031520.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675033080.0,
#      'comments': 'Departed:  26 minutes late.'},
#     {'station_code': 'NWK',
#      'scheduled_arrival_day': None,
#      'schedule_arrival_time': None,
#      'schedule_departure_day': '2',
#      'schedule_departure_time': 1675032300.0,
#      'actual_arrival_time': None,
#      'actual_departure_time': 1675034220.0,
#      'comments': 'Departed:  32 minutes late.'},
#     {'station_code': 'NYP',
#      'scheduled_arrival_day': '2',
#      'schedule_arrival_time': 1675206480.0,
#      'schedule_departure_day': None,
#      'schedule_departure_time': None,
#      'actual_arrival_time': 1675035300.0,
#      'actual_departure_time': None,
#      'comments': 'Arrived:  27 minutes late.'}]}}}
